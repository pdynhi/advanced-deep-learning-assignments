# %%
# !pip install gymnasium[toy-text]
# Out:
# Collecting gymnasium[toy-text]
#   Downloading gymnasium-0.29.0-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.8/953.8 kB 20.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[toy-text]) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[toy-text]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[toy-text]) (4.7.1)
# Collecting farama-notifications>=0.0.1 (from gymnasium[toy-text])
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium[toy-text]) (2.5.0)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.0

# %%
### Please do not change this code

# Load libraries
import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np
import random
import matplotlib
from keras.optimizers import Adam
from keras.layers import Dense
from keras.models import Sequential
from collections import deque
import imageio
import pandas as pd

# Initialize the environment\
env = gym.make('CliffWalking-v0', render_mode='rgb_array')
state_size = env.observation_space.n    # Number of states
action_size = env.action_space.n    # Number of actions of this game: four, 0: left, 1:down, 2: right, 3: up.
env.reset()    # Reset environment, i.e., set agent position to state 0
plt.imshow(env.render())    # Visualize environment map

# %%
# Define agent attibutes and methods
class Agent:
    def __init__(self, state_size, action_size):
        self.memory = deque(maxlen=2048)   # Deque is quick for append and pop operations from both the ends of the container.
        self.batch_size = 256    # Batch size of data samples for training policy (and target) network. In this example, the two networks are identical.
        self.learning_rate = 0.001    # Learning rate of
        self.epsilon = 1    # Start (max) value of epsilon
        self.min_eps = 0.01    # End (min) value of epsilon
        self.eps_decay = 0.003     # Decay factor for decreasing epsilon over episodes
        self.gamma = 0.9    # Discount factor
        self.state_size = state_size    # Number of states
        self.action_size =  action_size    # Number of possible actions the agent can take: four, 0: left, 1:down, 2: right, 3: up.
        self.episode = 0     # Agent current episode
        # self.epsilon_lst = []    # Track epsilon values over episodes
        self.max_steps = 400    # Maximum number of steps the agent can carry out in an episode
        self.train_episodes = 501    # Number of training episodes
        self.model = self.build_model()    # Agent policy (and target model)

    # Build model architecture and compile it
    def build_model(self):
        model = Sequential()    # Initiate a simple sequential model
        model.add(Dense(24, input_dim=self.state_size, activation='relu'))    # Add a fully connected layer
        model.add(Dense(24, input_dim=self.state_size, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))    # Add a fully connected layer connecting to the network output
        model.compile(loss='mse', optimizer=Adam(learning_rate=self.learning_rate))    # Compile model with Mean Squared Error loss function
        return model

    # Add an eposide to agent's memory
    def add_memory(self, state, action, reward, new_state, terminated):
        self.memory.append((state, action, reward, new_state, terminated))    # Insert the value in its argument to the right end of the deque

    # Get action when agent is at a certain state
    def action(self, state):
        if np.random.rand() > self.epsilon:     # Epsilon starts at 1. rand > epsilon: exploit, rand <= epsilon: explore.
            return np.argmax(self.model.predict(state, verbose=0))     # Take greedy action. Verbose=0 mutes output prediction log.
        return env.action_space.sample()    # Take a random action in the action space

    # Train policy (and target) network. In this example, the two networks are identical.
    def replay(self):
        ### Process data batch
        minibatch = random.sample(self.memory, self.batch_size)    # Select a data batch for training
        minibatch_state = np.concatenate(np.array(minibatch, dtype=object)[:, 0], axis=0)    # Extract 'state' batch from the data batch
        minibatch_action = np.array(minibatch, dtype=object)[:, 1]    # Extract 'action' batch from the data batch
        minibatch_reward = np.array(minibatch, dtype=object)[:, 2]    # Extract 'reward' batch from the data batch
        minibatch_new_state = np.concatenate(np.array(minibatch, dtype=object)[:, 3], axis=0)    # Extract 'new_state' batch from the data batch
        minibatch_terminated = np.array(minibatch, dtype=object)[:, 4]    # Extract 'terminated' batch from the data batch

        ### Feed state to the network for training
        q_state = self.model.predict(minibatch_state, verbose=0)    # First pass: feed current state to the network to get current Q-values
        q_new_state = self.model.predict(minibatch_new_state, verbose=0)    # Second pass: feed new state to the network to get next Q-values

        q_action_optimal = np.add(minibatch_reward, self.gamma * np.amax(q_new_state, axis=1))    # Calculate the optimal Q-values of actions from the current state
        for i in range(0, self.batch_size):
            q_state[i][minibatch_action[i]] = q_action_optimal[i]    # Update optimal Q-values back to 'q_state' variable

        self.model.fit(minibatch_state, q_state, epochs=1, verbose=0)    # Train the network with the optimal Q-values, i.e., now in 'q_state' variable. x is minibatch_state and y is q_state. Loss is MSE.

    # Save model
    def save_model(self, name):
        self.model.save_weights(name)

    # Load model
    def load_model(self, name):
        self.model.load_weights(name)

# Initialize a reinforcement learning agent
agent = Agent(state_size, action_size)

# %%
reward_episodes = []    # Track rewards over episodes
step_episodes = []    # Track number of steps (in each episode until termination) over episodes
epsilon_episodes = []    # Track epsilon values over episodes

for episode in range(agent.train_episodes):
    agent.episode = episode    # Set agent's current episode
    state = env.reset()    # Reset environment, i.e., agent position is set to state 0
    state_arr = np.zeros(agent.state_size)    # Initialze current state array, e.g., [0. 0. 0. 0. 0. 0. 0. 0. 0.]
    state_arr[state[0]] = 1    # Set the agent position in the current state array, i.e., [[1. 0. 0. 0. 0. 0. 0. 0. 0.]]
    state_arr = np.reshape(state_arr, [1, agent.state_size])    # Reshape array
    reward = 0    # Initialize reward to zero
    terminated = False    # Initialize terminated to False

    img_lst = [env.render()]    # Initialize list to store visualization frames
    for step in range(agent.max_steps):
        action = agent.action(state_arr)    # Take action at the current state. This ccan be exploitation or exploration, depending on agent.epsilon
        new_state, reward, terminated, info, _ = env.step(action)     # Terminated: whether a terminal state is reached after taking the action. Ref: https://www.gymlibrary.dev/api/core/#gym.Env.step
        new_state_arr = np.zeros(agent.state_size)    # Initialze new state array, e.g., [[0. 0. 0. 0. 0. 0. 0. 0. 0.]]
        new_state_arr[new_state] = 1    # Set the agent position in the new state array, after taking the action, e.g., [[0. 1. 0. 0. 0. 0. 0. 0. 0.]]
        new_state_arr = np.reshape(new_state_arr, [1, agent.state_size])    # Reshape array


        # Render map imgage for visualization every K episodes
        if agent.episode % 50 == 0:
            animation_file = "training_episode_" + str(agent.episode) + "_steps_" + str(step) + ".gif"
            img = env.render()    # Render current environment image
            img_lst.append(img)    # Append environment images to make animation

        if terminated:    # if agent reaches Goal
            reward += 100
            agent.add_memory(state_arr, action, reward, new_state_arr, terminated)
            break    # End episode

        agent.add_memory(state_arr, action, reward, new_state_arr, terminated)    # Add current step to agent's memory
        state_arr = new_state_arr    # New state becomes state

    print("Episode: " + str(agent.episode) + ", Steps: " + str(step) + ", epsilon: " + str(round(agent.epsilon,2)) + ", Reward: " + str(reward))
    reward_episodes.append(reward)    # Add reward to list for tracking purpose
    step_episodes.append(step)    # Add step to list for tracking purpose
    epsilon_episodes.append(agent.epsilon)    # Add epsilon to list for tracking purpose

    ### Update epsilon value which is the ratio of exploitation and exploration
    if agent.epsilon < agent.min_eps:
        agent.epsilon = agent.min_eps    # Set the minimum value of epsilon so that there is always a chance for exploration.
    else:
        agent.epsilon = np.exp(-agent.eps_decay*agent.episode)    # Decrease exploration / Increase exploitation overtime as the agent knows more about the environment

    ### If enough experiences collected in the memory, use them for training
    if len(agent.memory) > agent.batch_size:
        agent.replay()

    ### Write animation of the training episode (n*K)th
    if len(img_lst)>1:
        imageio.mimsave(animation_file, img_lst, format='GIF', duration=0.5)

print('Average success rate of training episodes: ', round(np.mean(reward_episodes),2))
agent.save_model('model_' + str(agent.episode))    # Save model
# Out:
# Episode: 0, Steps: 399, epsilon: 1, Reward: -1
# Episode: 1, Steps: 399, epsilon: 1.0, Reward: -1
# Episode: 2, Steps: 399, epsilon: 1.0, Reward: -1
# Episode: 3, Steps: 399, epsilon: 0.99, Reward: -1
# Episode: 4, Steps: 399, epsilon: 0.99, Reward: -1
# Episode: 5, Steps: 399, epsilon: 0.99, Reward: -1
# Episode: 6, Steps: 399, epsilon: 0.99, Reward: -1
# Episode: 7, Steps: 399, epsilon: 0.98, Reward: -1
# Episode: 8, Steps: 399, epsilon: 0.98, Reward: -1
# Episode: 9, Steps: 399, epsilon: 0.98, Reward: -1
# Episode: 10, Steps: 359, epsilon: 0.97, Reward: 99
# Episode: 11, Steps: 399, epsilon: 0.97, Reward: -1
# Episode: 12, Steps: 399, epsilon: 0.97, Reward: -1
# Episode: 13, Steps: 399, epsilon: 0.96, Reward: -1
# Episode: 14, Steps: 399, epsilon: 0.96, Reward: -1
# Episode: 15, Steps: 399, epsilon: 0.96, Reward: -1
# Episode: 16, Steps: 399, epsilon: 0.96, Reward: -1
# Episode: 17, Steps: 399, epsilon: 0.95, Reward: -1
# Episode: 18, Steps: 76, epsilon: 0.95, Reward: 99
# Episode: 19, Steps: 399, epsilon: 0.95, Reward: -1
# Episode: 20, Steps: 399, epsilon: 0.94, Reward: -1
# Episode: 21, Steps: 399, epsilon: 0.94, Reward: -1
# Episode: 22, Steps: 399, epsilon: 0.94, Reward: -1
# Episode: 23, Steps: 399, epsilon: 0.94, Reward: -1
# Episode: 24, Steps: 399, epsilon: 0.93, Reward: -1
# Episode: 25, Steps: 399, epsilon: 0.93, Reward: -1
# Episode: 26, Steps: 399, epsilon: 0.93, Reward: -1
# Episode: 27, Steps: 399, epsilon: 0.92, Reward: -1
# Episode: 28, Steps: 250, epsilon: 0.92, Reward: 99
# Episode: 29, Steps: 399, epsilon: 0.92, Reward: -1
# Episode: 30, Steps: 399, epsilon: 0.92, Reward: -1
# Episode: 31, Steps: 399, epsilon: 0.91, Reward: -1
# Episode: 32, Steps: 399, epsilon: 0.91, Reward: -1
# Episode: 33, Steps: 399, epsilon: 0.91, Reward: -1
# Episode: 34, Steps: 389, epsilon: 0.91, Reward: 99
# Episode: 35, Steps: 399, epsilon: 0.9, Reward: -1
# Episode: 36, Steps: 399, epsilon: 0.9, Reward: -1
# Episode: 37, Steps: 399, epsilon: 0.9, Reward: -1
# Episode: 38, Steps: 399, epsilon: 0.89, Reward: -1
# Episode: 39, Steps: 399, epsilon: 0.89, Reward: -1
# Episode: 40, Steps: 399, epsilon: 0.89, Reward: -1
# Episode: 41, Steps: 399, epsilon: 0.89, Reward: -1
# Episode: 42, Steps: 399, epsilon: 0.88, Reward: -100
# Episode: 43, Steps: 301, epsilon: 0.88, Reward: 99
# Episode: 44, Steps: 399, epsilon: 0.88, Reward: -1
# Episode: 45, Steps: 399, epsilon: 0.88, Reward: -1
# Episode: 46, Steps: 399, epsilon: 0.87, Reward: -1
# Episode: 47, Steps: 399, epsilon: 0.87, Reward: -1
# Episode: 48, Steps: 399, epsilon: 0.87, Reward: -100
# Episode: 49, Steps: 399, epsilon: 0.87, Reward: -1
# Episode: 50, Steps: 399, epsilon: 0.86, Reward: -1
# Episode: 51, Steps: 399, epsilon: 0.86, Reward: -1
# Episode: 52, Steps: 399, epsilon: 0.86, Reward: -1
# Episode: 53, Steps: 399, epsilon: 0.86, Reward: -1
# Episode: 54, Steps: 399, epsilon: 0.85, Reward: -1
# Episode: 55, Steps: 399, epsilon: 0.85, Reward: -1
# Episode: 56, Steps: 399, epsilon: 0.85, Reward: -1
# Episode: 57, Steps: 399, epsilon: 0.85, Reward: -1
# Episode: 58, Steps: 399, epsilon: 0.84, Reward: -1
# Episode: 59, Steps: 399, epsilon: 0.84, Reward: -1
# Episode: 60, Steps: 399, epsilon: 0.84, Reward: -1
# Episode: 61, Steps: 399, epsilon: 0.84, Reward: -1
# Episode: 62, Steps: 399, epsilon: 0.83, Reward: -1
# Episode: 63, Steps: 399, epsilon: 0.83, Reward: -1
# Episode: 64, Steps: 399, epsilon: 0.83, Reward: -1
# Episode: 65, Steps: 399, epsilon: 0.83, Reward: -1
# Episode: 66, Steps: 399, epsilon: 0.82, Reward: -1
# Episode: 67, Steps: 399, epsilon: 0.82, Reward: -1
# Episode: 68, Steps: 399, epsilon: 0.82, Reward: -1
# Episode: 69, Steps: 399, epsilon: 0.82, Reward: -1
# Episode: 70, Steps: 399, epsilon: 0.81, Reward: -1
# Episode: 71, Steps: 83, epsilon: 0.81, Reward: 99
# Episode: 72, Steps: 399, epsilon: 0.81, Reward: -1
# Episode: 73, Steps: 399, epsilon: 0.81, Reward: -1
# Episode: 74, Steps: 399, epsilon: 0.8, Reward: -1
# Episode: 75, Steps: 399, epsilon: 0.8, Reward: -1
# Episode: 76, Steps: 399, epsilon: 0.8, Reward: -1
# Episode: 77, Steps: 399, epsilon: 0.8, Reward: -1
# Episode: 78, Steps: 399, epsilon: 0.79, Reward: -1
# Episode: 79, Steps: 399, epsilon: 0.79, Reward: -1
# Episode: 80, Steps: 399, epsilon: 0.79, Reward: -1
# Episode: 81, Steps: 399, epsilon: 0.79, Reward: -1
# Episode: 82, Steps: 399, epsilon: 0.78, Reward: -1
# Episode: 83, Steps: 399, epsilon: 0.78, Reward: -1
# Episode: 84, Steps: 399, epsilon: 0.78, Reward: -1
# Episode: 85, Steps: 399, epsilon: 0.78, Reward: -1
# Episode: 86, Steps: 399, epsilon: 0.77, Reward: -1
# Episode: 87, Steps: 141, epsilon: 0.77, Reward: 99
# Episode: 88, Steps: 399, epsilon: 0.77, Reward: -1
# Episode: 89, Steps: 399, epsilon: 0.77, Reward: -1
# Episode: 90, Steps: 155, epsilon: 0.77, Reward: 99
# Episode: 91, Steps: 399, epsilon: 0.76, Reward: -1
# Episode: 92, Steps: 399, epsilon: 0.76, Reward: -1
# Episode: 93, Steps: 399, epsilon: 0.76, Reward: -1
# Episode: 94, Steps: 399, epsilon: 0.76, Reward: -1
# Episode: 95, Steps: 399, epsilon: 0.75, Reward: -1
# Episode: 96, Steps: 399, epsilon: 0.75, Reward: -1
# Episode: 97, Steps: 83, epsilon: 0.75, Reward: 99
# Episode: 98, Steps: 192, epsilon: 0.75, Reward: 99
# Episode: 99, Steps: 329, epsilon: 0.75, Reward: 99
# Episode: 100, Steps: 399, epsilon: 0.74, Reward: -1
# Episode: 101, Steps: 399, epsilon: 0.74, Reward: -1
# Episode: 102, Steps: 87, epsilon: 0.74, Reward: 99
# Episode: 103, Steps: 227, epsilon: 0.74, Reward: 99
# Episode: 104, Steps: 399, epsilon: 0.73, Reward: -1
# Episode: 105, Steps: 383, epsilon: 0.73, Reward: 99
# Episode: 106, Steps: 399, epsilon: 0.73, Reward: -1
# Episode: 107, Steps: 127, epsilon: 0.73, Reward: 99
# Episode: 108, Steps: 399, epsilon: 0.73, Reward: -1
# Episode: 109, Steps: 294, epsilon: 0.72, Reward: 99
# Episode: 110, Steps: 187, epsilon: 0.72, Reward: 99
# Episode: 111, Steps: 399, epsilon: 0.72, Reward: -1
# Episode: 112, Steps: 330, epsilon: 0.72, Reward: 99
# Episode: 113, Steps: 210, epsilon: 0.71, Reward: 99
# Episode: 114, Steps: 399, epsilon: 0.71, Reward: -1
# Episode: 115, Steps: 399, epsilon: 0.71, Reward: -1
# Episode: 116, Steps: 399, epsilon: 0.71, Reward: -1
# Episode: 117, Steps: 61, epsilon: 0.71, Reward: 99
# Episode: 118, Steps: 399, epsilon: 0.7, Reward: -1
# Episode: 119, Steps: 399, epsilon: 0.7, Reward: -1
# Episode: 120, Steps: 399, epsilon: 0.7, Reward: -1
# Episode: 121, Steps: 399, epsilon: 0.7, Reward: -1
# Episode: 122, Steps: 399, epsilon: 0.7, Reward: -1
# Episode: 123, Steps: 399, epsilon: 0.69, Reward: -1
# Episode: 124, Steps: 399, epsilon: 0.69, Reward: -1
# Episode: 125, Steps: 399, epsilon: 0.69, Reward: -1
# Episode: 126, Steps: 399, epsilon: 0.69, Reward: -1
# Episode: 127, Steps: 305, epsilon: 0.69, Reward: 99
# Episode: 128, Steps: 217, epsilon: 0.68, Reward: 99
# Episode: 129, Steps: 190, epsilon: 0.68, Reward: 99
# Episode: 130, Steps: 399, epsilon: 0.68, Reward: -1
# Episode: 131, Steps: 399, epsilon: 0.68, Reward: -1
# Episode: 132, Steps: 399, epsilon: 0.68, Reward: -1
# Episode: 133, Steps: 245, epsilon: 0.67, Reward: 99
# Episode: 134, Steps: 399, epsilon: 0.67, Reward: -1
# Episode: 135, Steps: 399, epsilon: 0.67, Reward: -1
# Episode: 136, Steps: 115, epsilon: 0.67, Reward: 99
# Episode: 137, Steps: 399, epsilon: 0.66, Reward: -1
# Episode: 138, Steps: 104, epsilon: 0.66, Reward: 99
# Episode: 139, Steps: 399, epsilon: 0.66, Reward: -1
# Episode: 140, Steps: 399, epsilon: 0.66, Reward: -1
# Episode: 141, Steps: 51, epsilon: 0.66, Reward: 99
# Episode: 142, Steps: 168, epsilon: 0.66, Reward: 99
# Episode: 143, Steps: 169, epsilon: 0.65, Reward: 99
# Episode: 144, Steps: 46, epsilon: 0.65, Reward: 99
# Episode: 145, Steps: 71, epsilon: 0.65, Reward: 99
# Episode: 146, Steps: 399, epsilon: 0.65, Reward: -1
# Episode: 147, Steps: 112, epsilon: 0.65, Reward: 99
# Episode: 148, Steps: 79, epsilon: 0.64, Reward: 99
# Episode: 149, Steps: 188, epsilon: 0.64, Reward: 99
# Episode: 150, Steps: 399, epsilon: 0.64, Reward: -1
# Episode: 151, Steps: 399, epsilon: 0.64, Reward: -1
# Episode: 152, Steps: 399, epsilon: 0.64, Reward: -1
# Episode: 153, Steps: 399, epsilon: 0.63, Reward: -100
# Episode: 154, Steps: 399, epsilon: 0.63, Reward: -1
# Episode: 155, Steps: 262, epsilon: 0.63, Reward: 99
# Episode: 156, Steps: 399, epsilon: 0.63, Reward: -1
# Episode: 157, Steps: 399, epsilon: 0.63, Reward: -1
# Episode: 158, Steps: 399, epsilon: 0.62, Reward: -1
# Episode: 159, Steps: 399, epsilon: 0.62, Reward: -1
# Episode: 160, Steps: 399, epsilon: 0.62, Reward: -1
# Episode: 161, Steps: 399, epsilon: 0.62, Reward: -1
# Episode: 162, Steps: 399, epsilon: 0.62, Reward: -1
# Episode: 163, Steps: 399, epsilon: 0.62, Reward: -1
# Episode: 164, Steps: 399, epsilon: 0.61, Reward: -1
# Episode: 165, Steps: 399, epsilon: 0.61, Reward: -1
# Episode: 166, Steps: 177, epsilon: 0.61, Reward: 99
# Episode: 167, Steps: 399, epsilon: 0.61, Reward: -1
# Episode: 168, Steps: 297, epsilon: 0.61, Reward: 99
# Episode: 169, Steps: 399, epsilon: 0.6, Reward: -1
# Episode: 170, Steps: 399, epsilon: 0.6, Reward: -100
# Episode: 171, Steps: 399, epsilon: 0.6, Reward: -1
# Episode: 172, Steps: 399, epsilon: 0.6, Reward: -1
# Episode: 173, Steps: 399, epsilon: 0.6, Reward: -1
# Episode: 174, Steps: 399, epsilon: 0.6, Reward: -1
# Episode: 175, Steps: 399, epsilon: 0.59, Reward: -1
# Episode: 176, Steps: 399, epsilon: 0.59, Reward: -1
# Episode: 177, Steps: 399, epsilon: 0.59, Reward: -1
# Episode: 178, Steps: 399, epsilon: 0.59, Reward: -1
# Episode: 179, Steps: 399, epsilon: 0.59, Reward: -1
# Episode: 180, Steps: 399, epsilon: 0.58, Reward: -1
# Episode: 181, Steps: 399, epsilon: 0.58, Reward: -100
# Episode: 182, Steps: 337, epsilon: 0.58, Reward: 99
# Episode: 183, Steps: 399, epsilon: 0.58, Reward: -1
# Episode: 184, Steps: 399, epsilon: 0.58, Reward: -1
# Episode: 185, Steps: 399, epsilon: 0.58, Reward: -1
# Episode: 186, Steps: 399, epsilon: 0.57, Reward: -1
# Episode: 187, Steps: 399, epsilon: 0.57, Reward: -1
# Episode: 188, Steps: 399, epsilon: 0.57, Reward: -1
# Episode: 189, Steps: 399, epsilon: 0.57, Reward: -1
# Episode: 190, Steps: 399, epsilon: 0.57, Reward: -1
# Episode: 191, Steps: 399, epsilon: 0.57, Reward: -1
# Episode: 192, Steps: 399, epsilon: 0.56, Reward: -1
# Episode: 193, Steps: 399, epsilon: 0.56, Reward: -1
# Episode: 194, Steps: 399, epsilon: 0.56, Reward: -100
# Episode: 195, Steps: 399, epsilon: 0.56, Reward: -1
# Episode: 196, Steps: 399, epsilon: 0.56, Reward: -1
# Episode: 197, Steps: 399, epsilon: 0.56, Reward: -1
# Episode: 198, Steps: 399, epsilon: 0.55, Reward: -1
# Episode: 199, Steps: 399, epsilon: 0.55, Reward: -1
# Episode: 200, Steps: 399, epsilon: 0.55, Reward: -1
# Episode: 201, Steps: 399, epsilon: 0.55, Reward: -1
# Episode: 202, Steps: 270, epsilon: 0.55, Reward: 99
# Episode: 203, Steps: 399, epsilon: 0.55, Reward: -1
# Episode: 204, Steps: 399, epsilon: 0.54, Reward: -1
# Episode: 205, Steps: 399, epsilon: 0.54, Reward: -1
# Episode: 206, Steps: 399, epsilon: 0.54, Reward: -1
# Episode: 207, Steps: 399, epsilon: 0.54, Reward: -1
# Episode: 208, Steps: 399, epsilon: 0.54, Reward: -1
# Episode: 209, Steps: 399, epsilon: 0.54, Reward: -1
# Episode: 210, Steps: 399, epsilon: 0.53, Reward: -1
# Episode: 211, Steps: 399, epsilon: 0.53, Reward: -1
# Episode: 212, Steps: 399, epsilon: 0.53, Reward: -1
# Episode: 213, Steps: 399, epsilon: 0.53, Reward: -1
# Episode: 214, Steps: 399, epsilon: 0.53, Reward: -1
# Episode: 215, Steps: 399, epsilon: 0.53, Reward: -1
# Episode: 216, Steps: 399, epsilon: 0.52, Reward: -1
# Episode: 217, Steps: 399, epsilon: 0.52, Reward: -1
# Episode: 218, Steps: 399, epsilon: 0.52, Reward: -1
# Episode: 219, Steps: 399, epsilon: 0.52, Reward: -1
# Episode: 220, Steps: 33, epsilon: 0.52, Reward: 99
# Episode: 221, Steps: 399, epsilon: 0.52, Reward: -1
# Episode: 222, Steps: 399, epsilon: 0.52, Reward: -1
# Episode: 223, Steps: 399, epsilon: 0.51, Reward: -1
# Episode: 224, Steps: 399, epsilon: 0.51, Reward: -1
# Episode: 225, Steps: 399, epsilon: 0.51, Reward: -1
# Episode: 226, Steps: 399, epsilon: 0.51, Reward: -1
# Episode: 227, Steps: 399, epsilon: 0.51, Reward: -1
# Episode: 228, Steps: 399, epsilon: 0.51, Reward: -1
# Episode: 229, Steps: 399, epsilon: 0.5, Reward: -1
# Episode: 230, Steps: 399, epsilon: 0.5, Reward: -1
# Episode: 231, Steps: 399, epsilon: 0.5, Reward: -1
# Episode: 232, Steps: 399, epsilon: 0.5, Reward: -1
# Episode: 233, Steps: 399, epsilon: 0.5, Reward: -1
# Episode: 234, Steps: 399, epsilon: 0.5, Reward: -1
# Episode: 235, Steps: 399, epsilon: 0.5, Reward: -1
# Episode: 236, Steps: 399, epsilon: 0.49, Reward: -1
# Episode: 237, Steps: 399, epsilon: 0.49, Reward: -1
# Episode: 238, Steps: 146, epsilon: 0.49, Reward: 99
# Episode: 239, Steps: 399, epsilon: 0.49, Reward: -1
# Episode: 240, Steps: 108, epsilon: 0.49, Reward: 99
# Episode: 241, Steps: 399, epsilon: 0.49, Reward: -1
# Episode: 242, Steps: 399, epsilon: 0.49, Reward: -1
# Episode: 243, Steps: 399, epsilon: 0.48, Reward: -1
# Episode: 244, Steps: 399, epsilon: 0.48, Reward: -1
# Episode: 245, Steps: 382, epsilon: 0.48, Reward: 99
# Episode: 246, Steps: 399, epsilon: 0.48, Reward: -1
# Episode: 247, Steps: 261, epsilon: 0.48, Reward: 99
# Episode: 248, Steps: 399, epsilon: 0.48, Reward: -1
# Episode: 249, Steps: 305, epsilon: 0.48, Reward: 99
# Episode: 250, Steps: 399, epsilon: 0.47, Reward: -1
# Episode: 251, Steps: 399, epsilon: 0.47, Reward: -1
# Episode: 252, Steps: 399, epsilon: 0.47, Reward: -1
# Episode: 253, Steps: 389, epsilon: 0.47, Reward: 99
# Episode: 254, Steps: 399, epsilon: 0.47, Reward: -100
# Episode: 255, Steps: 18, epsilon: 0.47, Reward: 99
# Episode: 256, Steps: 399, epsilon: 0.47, Reward: -1
# Episode: 257, Steps: 399, epsilon: 0.46, Reward: -1
# Episode: 258, Steps: 399, epsilon: 0.46, Reward: -1
# Episode: 259, Steps: 73, epsilon: 0.46, Reward: 99
# Episode: 260, Steps: 56, epsilon: 0.46, Reward: 99
# Episode: 261, Steps: 399, epsilon: 0.46, Reward: -1
# Episode: 262, Steps: 150, epsilon: 0.46, Reward: 99
# Episode: 263, Steps: 135, epsilon: 0.46, Reward: 99
# Episode: 264, Steps: 75, epsilon: 0.45, Reward: 99
# Episode: 265, Steps: 154, epsilon: 0.45, Reward: 99
# Episode: 266, Steps: 83, epsilon: 0.45, Reward: 99
# Episode: 267, Steps: 399, epsilon: 0.45, Reward: -1
# Episode: 268, Steps: 132, epsilon: 0.45, Reward: 99
# Episode: 269, Steps: 399, epsilon: 0.45, Reward: -1
# Episode: 270, Steps: 337, epsilon: 0.45, Reward: 99
# Episode: 271, Steps: 242, epsilon: 0.44, Reward: 99
# Episode: 272, Steps: 399, epsilon: 0.44, Reward: -1
# Episode: 273, Steps: 237, epsilon: 0.44, Reward: 99
# Episode: 274, Steps: 42, epsilon: 0.44, Reward: 99
# Episode: 275, Steps: 399, epsilon: 0.44, Reward: -100
# Episode: 276, Steps: 399, epsilon: 0.44, Reward: -1
# Episode: 277, Steps: 17, epsilon: 0.44, Reward: 99
# Episode: 278, Steps: 23, epsilon: 0.44, Reward: 99
# Episode: 279, Steps: 243, epsilon: 0.43, Reward: 99
# Episode: 280, Steps: 28, epsilon: 0.43, Reward: 99
# Episode: 281, Steps: 18, epsilon: 0.43, Reward: 99
# Episode: 282, Steps: 37, epsilon: 0.43, Reward: 99
# Episode: 283, Steps: 45, epsilon: 0.43, Reward: 99
# Episode: 284, Steps: 49, epsilon: 0.43, Reward: 99
# Episode: 285, Steps: 30, epsilon: 0.43, Reward: 99
# Episode: 286, Steps: 27, epsilon: 0.43, Reward: 99
# Episode: 287, Steps: 86, epsilon: 0.42, Reward: 99
# Episode: 288, Steps: 33, epsilon: 0.42, Reward: 99
# Episode: 289, Steps: 106, epsilon: 0.42, Reward: 99
# Episode: 290, Steps: 22, epsilon: 0.42, Reward: 99
# Episode: 291, Steps: 49, epsilon: 0.42, Reward: 99
# Episode: 292, Steps: 34, epsilon: 0.42, Reward: 99
# Episode: 293, Steps: 23, epsilon: 0.42, Reward: 99
# Episode: 294, Steps: 25, epsilon: 0.42, Reward: 99
# Episode: 295, Steps: 96, epsilon: 0.41, Reward: 99
# Episode: 296, Steps: 131, epsilon: 0.41, Reward: 99
# Episode: 297, Steps: 18, epsilon: 0.41, Reward: 99
# Episode: 298, Steps: 36, epsilon: 0.41, Reward: 99
# Episode: 299, Steps: 34, epsilon: 0.41, Reward: 99
# Episode: 300, Steps: 55, epsilon: 0.41, Reward: 99
# Episode: 301, Steps: 26, epsilon: 0.41, Reward: 99
# Episode: 302, Steps: 22, epsilon: 0.41, Reward: 99
# Episode: 303, Steps: 42, epsilon: 0.4, Reward: 99
# Episode: 304, Steps: 36, epsilon: 0.4, Reward: 99
# Episode: 305, Steps: 231, epsilon: 0.4, Reward: 99
# Episode: 306, Steps: 96, epsilon: 0.4, Reward: 99
# Episode: 307, Steps: 91, epsilon: 0.4, Reward: 99
# Episode: 308, Steps: 77, epsilon: 0.4, Reward: 99
# Episode: 309, Steps: 18, epsilon: 0.4, Reward: 99
# Episode: 310, Steps: 80, epsilon: 0.4, Reward: 99
# Episode: 311, Steps: 126, epsilon: 0.39, Reward: 99
# Episode: 312, Steps: 33, epsilon: 0.39, Reward: 99
# Episode: 313, Steps: 74, epsilon: 0.39, Reward: 99
# Episode: 314, Steps: 40, epsilon: 0.39, Reward: 99
# Episode: 315, Steps: 14, epsilon: 0.39, Reward: 99
# Episode: 316, Steps: 29, epsilon: 0.39, Reward: 99
# Episode: 317, Steps: 39, epsilon: 0.39, Reward: 99
# Episode: 318, Steps: 141, epsilon: 0.39, Reward: 99
# Episode: 319, Steps: 48, epsilon: 0.39, Reward: 99
# Episode: 320, Steps: 31, epsilon: 0.38, Reward: 99
# Episode: 321, Steps: 45, epsilon: 0.38, Reward: 99
# Episode: 322, Steps: 27, epsilon: 0.38, Reward: 99
# Episode: 323, Steps: 97, epsilon: 0.38, Reward: 99
# Episode: 324, Steps: 75, epsilon: 0.38, Reward: 99
# Episode: 325, Steps: 36, epsilon: 0.38, Reward: 99
# Episode: 326, Steps: 40, epsilon: 0.38, Reward: 99
# Episode: 327, Steps: 171, epsilon: 0.38, Reward: 99
# Episode: 328, Steps: 43, epsilon: 0.37, Reward: 99
# Episode: 329, Steps: 18, epsilon: 0.37, Reward: 99
# Episode: 330, Steps: 93, epsilon: 0.37, Reward: 99
# Episode: 331, Steps: 64, epsilon: 0.37, Reward: 99
# Episode: 332, Steps: 29, epsilon: 0.37, Reward: 99
# Episode: 333, Steps: 40, epsilon: 0.37, Reward: 99
# Episode: 334, Steps: 88, epsilon: 0.37, Reward: 99
# Episode: 335, Steps: 57, epsilon: 0.37, Reward: 99
# Episode: 336, Steps: 14, epsilon: 0.37, Reward: 99
# Episode: 337, Steps: 130, epsilon: 0.36, Reward: 99
# Episode: 338, Steps: 48, epsilon: 0.36, Reward: 99
# Episode: 339, Steps: 54, epsilon: 0.36, Reward: 99
# Episode: 340, Steps: 40, epsilon: 0.36, Reward: 99
# Episode: 341, Steps: 92, epsilon: 0.36, Reward: 99
# Episode: 342, Steps: 281, epsilon: 0.36, Reward: 99
# Episode: 343, Steps: 31, epsilon: 0.36, Reward: 99
# Episode: 344, Steps: 58, epsilon: 0.36, Reward: 99
# Episode: 345, Steps: 27, epsilon: 0.36, Reward: 99
# Episode: 346, Steps: 25, epsilon: 0.36, Reward: 99
# Episode: 347, Steps: 122, epsilon: 0.35, Reward: 99
# Episode: 348, Steps: 45, epsilon: 0.35, Reward: 99
# Episode: 349, Steps: 67, epsilon: 0.35, Reward: 99
# Episode: 350, Steps: 36, epsilon: 0.35, Reward: 99
# Episode: 351, Steps: 31, epsilon: 0.35, Reward: 99
# Episode: 352, Steps: 16, epsilon: 0.35, Reward: 99
# Episode: 353, Steps: 33, epsilon: 0.35, Reward: 99
# Episode: 354, Steps: 28, epsilon: 0.35, Reward: 99
# Episode: 355, Steps: 29, epsilon: 0.35, Reward: 99
# Episode: 356, Steps: 77, epsilon: 0.34, Reward: 99
# Episode: 357, Steps: 52, epsilon: 0.34, Reward: 99
# Episode: 358, Steps: 59, epsilon: 0.34, Reward: 99
# Episode: 359, Steps: 56, epsilon: 0.34, Reward: 99
# Episode: 360, Steps: 28, epsilon: 0.34, Reward: 99
# Episode: 361, Steps: 40, epsilon: 0.34, Reward: 99
# Episode: 362, Steps: 37, epsilon: 0.34, Reward: 99
# Episode: 363, Steps: 40, epsilon: 0.34, Reward: 99
# Episode: 364, Steps: 31, epsilon: 0.34, Reward: 99
# Episode: 365, Steps: 12, epsilon: 0.34, Reward: 99
# Episode: 366, Steps: 132, epsilon: 0.33, Reward: 99
# Episode: 367, Steps: 25, epsilon: 0.33, Reward: 99
# Episode: 368, Steps: 63, epsilon: 0.33, Reward: 99
# Episode: 369, Steps: 42, epsilon: 0.33, Reward: 99
# Episode: 370, Steps: 14, epsilon: 0.33, Reward: 99
# Episode: 371, Steps: 18, epsilon: 0.33, Reward: 99
# Episode: 372, Steps: 123, epsilon: 0.33, Reward: 99
# Episode: 373, Steps: 48, epsilon: 0.33, Reward: 99
# Episode: 374, Steps: 27, epsilon: 0.33, Reward: 99
# Episode: 375, Steps: 14, epsilon: 0.33, Reward: 99
# Episode: 376, Steps: 51, epsilon: 0.32, Reward: 99
# Episode: 377, Steps: 23, epsilon: 0.32, Reward: 99
# Episode: 378, Steps: 76, epsilon: 0.32, Reward: 99
# Episode: 379, Steps: 23, epsilon: 0.32, Reward: 99
# Episode: 380, Steps: 36, epsilon: 0.32, Reward: 99
# Episode: 381, Steps: 29, epsilon: 0.32, Reward: 99
# Episode: 382, Steps: 18, epsilon: 0.32, Reward: 99
# Episode: 383, Steps: 32, epsilon: 0.32, Reward: 99
# Episode: 384, Steps: 123, epsilon: 0.32, Reward: 99
# Episode: 385, Steps: 91, epsilon: 0.32, Reward: 99
# Episode: 386, Steps: 13, epsilon: 0.32, Reward: 99
# Episode: 387, Steps: 16, epsilon: 0.31, Reward: 99
# Episode: 388, Steps: 21, epsilon: 0.31, Reward: 99
# Episode: 389, Steps: 38, epsilon: 0.31, Reward: 99
# Episode: 390, Steps: 20, epsilon: 0.31, Reward: 99
# Episode: 391, Steps: 76, epsilon: 0.31, Reward: 99
# Episode: 392, Steps: 28, epsilon: 0.31, Reward: 99
# Episode: 393, Steps: 31, epsilon: 0.31, Reward: 99
# Episode: 394, Steps: 62, epsilon: 0.31, Reward: 99
# Episode: 395, Steps: 38, epsilon: 0.31, Reward: 99
# Episode: 396, Steps: 16, epsilon: 0.31, Reward: 99
# Episode: 397, Steps: 16, epsilon: 0.3, Reward: 99
# Episode: 398, Steps: 89, epsilon: 0.3, Reward: 99
# Episode: 399, Steps: 38, epsilon: 0.3, Reward: 99
# Episode: 400, Steps: 40, epsilon: 0.3, Reward: 99
# Episode: 401, Steps: 23, epsilon: 0.3, Reward: 99
# Episode: 402, Steps: 27, epsilon: 0.3, Reward: 99
# Episode: 403, Steps: 45, epsilon: 0.3, Reward: 99
# Episode: 404, Steps: 22, epsilon: 0.3, Reward: 99
# Episode: 405, Steps: 16, epsilon: 0.3, Reward: 99
# Episode: 406, Steps: 16, epsilon: 0.3, Reward: 99
# Episode: 407, Steps: 56, epsilon: 0.3, Reward: 99
# Episode: 408, Steps: 14, epsilon: 0.29, Reward: 99
# Episode: 409, Steps: 40, epsilon: 0.29, Reward: 99
# Episode: 410, Steps: 16, epsilon: 0.29, Reward: 99
# Episode: 411, Steps: 23, epsilon: 0.29, Reward: 99
# Episode: 412, Steps: 45, epsilon: 0.29, Reward: 99
# Episode: 413, Steps: 22, epsilon: 0.29, Reward: 99
# Episode: 414, Steps: 49, epsilon: 0.29, Reward: 99
# Episode: 415, Steps: 12, epsilon: 0.29, Reward: 99
# Episode: 416, Steps: 20, epsilon: 0.29, Reward: 99
# Episode: 417, Steps: 30, epsilon: 0.29, Reward: 99
# Episode: 418, Steps: 60, epsilon: 0.29, Reward: 99
# Episode: 419, Steps: 64, epsilon: 0.29, Reward: 99
# Episode: 420, Steps: 39, epsilon: 0.28, Reward: 99
# Episode: 421, Steps: 21, epsilon: 0.28, Reward: 99
# Episode: 422, Steps: 16, epsilon: 0.28, Reward: 99
# Episode: 423, Steps: 18, epsilon: 0.28, Reward: 99
# Episode: 424, Steps: 12, epsilon: 0.28, Reward: 99
# Episode: 425, Steps: 111, epsilon: 0.28, Reward: 99
# Episode: 426, Steps: 23, epsilon: 0.28, Reward: 99
# Episode: 427, Steps: 12, epsilon: 0.28, Reward: 99
# Episode: 428, Steps: 30, epsilon: 0.28, Reward: 99
# Episode: 429, Steps: 89, epsilon: 0.28, Reward: 99
# Episode: 430, Steps: 27, epsilon: 0.28, Reward: 99
# Episode: 431, Steps: 16, epsilon: 0.28, Reward: 99
# Episode: 432, Steps: 13, epsilon: 0.27, Reward: 99
# Episode: 433, Steps: 30, epsilon: 0.27, Reward: 99
# Episode: 434, Steps: 22, epsilon: 0.27, Reward: 99
# Episode: 435, Steps: 95, epsilon: 0.27, Reward: 99
# Episode: 436, Steps: 21, epsilon: 0.27, Reward: 99
# Episode: 437, Steps: 30, epsilon: 0.27, Reward: 99
# Episode: 438, Steps: 19, epsilon: 0.27, Reward: 99
# Episode: 439, Steps: 16, epsilon: 0.27, Reward: 99
# Episode: 440, Steps: 22, epsilon: 0.27, Reward: 99
# Episode: 441, Steps: 20, epsilon: 0.27, Reward: 99
# Episode: 442, Steps: 12, epsilon: 0.27, Reward: 99
# Episode: 443, Steps: 27, epsilon: 0.27, Reward: 99
# Episode: 444, Steps: 28, epsilon: 0.26, Reward: 99
# Episode: 445, Steps: 22, epsilon: 0.26, Reward: 99
# Episode: 446, Steps: 14, epsilon: 0.26, Reward: 99
# Episode: 447, Steps: 40, epsilon: 0.26, Reward: 99
# Episode: 448, Steps: 30, epsilon: 0.26, Reward: 99
# Episode: 449, Steps: 28, epsilon: 0.26, Reward: 99
# Episode: 450, Steps: 14, epsilon: 0.26, Reward: 99
# Episode: 451, Steps: 12, epsilon: 0.26, Reward: 99
# Episode: 452, Steps: 51, epsilon: 0.26, Reward: 99
# Episode: 453, Steps: 20, epsilon: 0.26, Reward: 99
# Episode: 454, Steps: 26, epsilon: 0.26, Reward: 99
# Episode: 455, Steps: 93, epsilon: 0.26, Reward: 99
# Episode: 456, Steps: 16, epsilon: 0.26, Reward: 99
# Episode: 457, Steps: 29, epsilon: 0.25, Reward: 99
# Episode: 458, Steps: 33, epsilon: 0.25, Reward: 99
# Episode: 459, Steps: 18, epsilon: 0.25, Reward: 99
# Episode: 460, Steps: 59, epsilon: 0.25, Reward: 99
# Episode: 461, Steps: 53, epsilon: 0.25, Reward: 99
# Episode: 462, Steps: 23, epsilon: 0.25, Reward: 99
# Episode: 463, Steps: 72, epsilon: 0.25, Reward: 99
# Episode: 464, Steps: 16, epsilon: 0.25, Reward: 99
# Episode: 465, Steps: 17, epsilon: 0.25, Reward: 99
# Episode: 466, Steps: 35, epsilon: 0.25, Reward: 99
# Episode: 467, Steps: 15, epsilon: 0.25, Reward: 99
# Episode: 468, Steps: 32, epsilon: 0.25, Reward: 99
# Episode: 469, Steps: 12, epsilon: 0.25, Reward: 99
# Episode: 470, Steps: 25, epsilon: 0.24, Reward: 99
# Episode: 471, Steps: 17, epsilon: 0.24, Reward: 99
# Episode: 472, Steps: 28, epsilon: 0.24, Reward: 99
# Episode: 473, Steps: 43, epsilon: 0.24, Reward: 99
# Episode: 474, Steps: 14, epsilon: 0.24, Reward: 99
# Episode: 475, Steps: 12, epsilon: 0.24, Reward: 99
# Episode: 476, Steps: 29, epsilon: 0.24, Reward: 99
# Episode: 477, Steps: 24, epsilon: 0.24, Reward: 99
# Episode: 478, Steps: 16, epsilon: 0.24, Reward: 99
# Episode: 479, Steps: 17, epsilon: 0.24, Reward: 99
# Episode: 480, Steps: 12, epsilon: 0.24, Reward: 99
# Episode: 481, Steps: 17, epsilon: 0.24, Reward: 99
# Episode: 482, Steps: 16, epsilon: 0.24, Reward: 99
# Episode: 483, Steps: 34, epsilon: 0.24, Reward: 99
# Episode: 484, Steps: 14, epsilon: 0.23, Reward: 99
# Episode: 485, Steps: 45, epsilon: 0.23, Reward: 99
# Episode: 486, Steps: 14, epsilon: 0.23, Reward: 99
# Episode: 487, Steps: 65, epsilon: 0.23, Reward: 99
# Episode: 488, Steps: 22, epsilon: 0.23, Reward: 99
# Episode: 489, Steps: 20, epsilon: 0.23, Reward: 99
# Episode: 490, Steps: 19, epsilon: 0.23, Reward: 99
# Episode: 491, Steps: 20, epsilon: 0.23, Reward: 99
# Episode: 492, Steps: 14, epsilon: 0.23, Reward: 99
# Episode: 493, Steps: 14, epsilon: 0.23, Reward: 99
# Episode: 494, Steps: 12, epsilon: 0.23, Reward: 99
# Episode: 495, Steps: 20, epsilon: 0.23, Reward: 99
# Episode: 496, Steps: 35, epsilon: 0.23, Reward: 99
# Episode: 497, Steps: 12, epsilon: 0.23, Reward: 99
# Episode: 498, Steps: 17, epsilon: 0.23, Reward: 99
# Episode: 499, Steps: 31, epsilon: 0.22, Reward: 99
# Episode: 500, Steps: 28, epsilon: 0.22, Reward: 99
# Average success rate of training episodes:  53.91

# %%
# Plot cumulative average reward (or success rate) of the training phase.
# This shows how well the agent performs in the training phase.
df_reward_episodes = pd.DataFrame(reward_episodes)
cumulative_average_rewards = df_reward_episodes.expanding().mean()
plt.plot(cumulative_average_rewards)
plt.ylabel('Cumulative average reward')
plt.xlabel('Episodes')
plt.legend(['Training'], loc='upper left')
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %%
# Plot cumulative average steps of the training phase.
# This shows how well the agent performs in the training phase.
df_step_episodes = pd.DataFrame(step_episodes)
cumulative_average_steps = df_step_episodes.expanding().mean()
plt.plot(cumulative_average_steps)
plt.ylabel('Cumulative average step')
plt.xlabel('Episodes')
plt.legend(['Training'], loc='upper left')
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %%
# Plot epsilon values over episodes
plt.plot(epsilon_episodes)
plt.ylabel('Epsilon value')
plt.xlabel('Episodes')
plt.legend(['Training'], loc='upper right')
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %%
# Print the optimal policy, i.e., at each state what is the best action to take.
for state_index in range(agent.state_size):
    state_arr=np.zeros(agent.state_size)    # Initialize state array, e.g., [[0. 0. 0. 0. 0. 0. 0. 0. 0.]]
    state_arr[state_index] = 1    # Set the agent position as if it is currently at each of the state
    state_arr= np.reshape(state_arr, [1, agent.state_size])    # Reshape state array
    q_values = agent.model.predict(state_arr, verbose=0)    # Get Q-values of all actions of the current state
    best_action = np.argmax(q_values)    # # Get max-Q-value action, i.e., best action to take
    print("State " + str(state_index) + ", Best action: " + str(best_action))
# Out:
# State 0, Best action: 2
# State 1, Best action: 2
# State 2, Best action: 1
# State 3, Best action: 1
# State 4, Best action: 1
# State 5, Best action: 1
# State 6, Best action: 1
# State 7, Best action: 1
# State 8, Best action: 2
# State 9, Best action: 2
# State 10, Best action: 2
# State 11, Best action: 2
# State 12, Best action: 2
# State 13, Best action: 1
# State 14, Best action: 1
# State 15, Best action: 1
# State 16, Best action: 1
# State 17, Best action: 1
# State 18, Best action: 1
# State 19, Best action: 1
# State 20, Best action: 2
# State 21, Best action: 2
# State 22, Best action: 2
# State 23, Best action: 2
# State 24, Best action: 1
# State 25, Best action: 1
# State 26, Best action: 1
# State 27, Best action: 1
# State 28, Best action: 1
# State 29, Best action: 1
# State 30, Best action: 1
# State 31, Best action: 1
# State 32, Best action: 1
# State 33, Best action: 1
# State 34, Best action: 1
# State 35, Best action: 2
# State 36, Best action: 0
# State 37, Best action: 1
# State 38, Best action: 3
# State 39, Best action: 3
# State 40, Best action: 0
# State 41, Best action: 1
# State 42, Best action: 3
# State 43, Best action: 1
# State 44, Best action: 3
# State 45, Best action: 1
# State 46, Best action: 1
# State 47, Best action: 1

# %%
# Load the saved agent model.
# agent.load_model('model_500')    # Uncomment this line if you want to load a saved model from file

# Test an episode
state = env.reset()    # Reset environment, i.e., agent position is set to state 0
state_arr = np.zeros(agent.state_size)    # Initialze current state array, e.g., [0. 0. 0. 0. 0. 0. 0. 0. 0.]
state_arr[state[0]] = 1    # Set the agent position in the current state array, i.e., [1. 0. 0. 0. 0. 0. 0. 0. 0.]
state_arr = np.reshape(state_arr, [1, agent.state_size])    # Reshape array, e.g., [[1. 0. 0. 0. 0. 0. 0. 0. 0.]]
terminated = False    # Initialize terminated to False
img_lst = [env.render()]    # Initialize list to store visualization frames
for step in range(agent.max_steps):
    q_values = agent.model.predict(state_arr, verbose=0)    # Get Q-values of all actions of the current state
    best_action = np.argmax(q_values)    # Get max-Q-value action, i.e., best action to take
    new_state, reward, terminated, info, _ = env.step(best_action)    # Perform the best action, get return from environment
    new_state_arr = np.zeros(agent.state_size)    # Initialze new state array, e.g., [0. 0. 0. 0. 0. 0. 0. 0. 0.]
    new_state_arr[new_state] = 1    # Set the agent position in the new state array, after taking the action, e.g., [0. 1. 0. 0. 0. 0. 0. 0. 0.]
    new_state_arr = np.reshape(new_state_arr, [1, agent.state_size])    # Reshape array, e.g., [[0. 1. 0. 0. 0. 0. 0. 0. 0.]]
    print("Current state: " + str(np.argmax(state_arr)) + ", Action: " + str(best_action) + ", New state: " + str(np.argmax(new_state_arr)))
    state_arr = new_state_arr    # New state becomes state

    img = env.render()    # Render current environment image
    img_lst.append(img)    # Append environment images to make animation

    if terminated:    # If agent reaches Goal or Hole
        reward +=100
        break    # End episode

print("Reward: " + str(reward))    # Print reward of the test episode
imageio.mimsave('test.gif', img_lst, format='GIF', duration=0.5)
# Out:
# Current state: 36, Action: 0, New state: 24
# Current state: 24, Action: 1, New state: 25
# Current state: 25, Action: 1, New state: 26
# Current state: 26, Action: 1, New state: 27
# Current state: 27, Action: 1, New state: 28
# Current state: 28, Action: 1, New state: 29
# Current state: 29, Action: 1, New state: 30
# Current state: 30, Action: 1, New state: 31
# Current state: 31, Action: 1, New state: 32
# Current state: 32, Action: 1, New state: 33
# Current state: 33, Action: 1, New state: 34
# Current state: 34, Action: 1, New state: 35
# Current state: 35, Action: 2, New state: 47
# Reward: 99

# %%
# Display test result animation
from IPython.display import Image
Image('test.gif')
